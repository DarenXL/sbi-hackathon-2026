# %% [markdown]
# # SBI 2026 : Gaussian process

# %% [markdown]
# The goal of PhD thesis is to find an alternative to the Maximum LIkelihood Estimation (MLE). I'd like to know how SBI can be used in this purpose.

# %% [markdown]
# **Workflow:**
#
# * Simulator and prior : OK (see github)
# * Choose component for simulation based inference
#     * Data representation : 1D time 1D space => grid of values / images (could be a graph)
#     * inference algorithm : NLE in first place (might have a lot of observation)
#     * inference network : CNN
# * Execute simulation based inference
#     * Simulate dataset
#     * train neural network
#     * perform inference
# * Diagnostic inference
# * Analyze posterior

# %%
import matplotlib.pyplot as plt

import numpy as np

import random
from tqdm import tqdm
import time
import os
import joblib

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import Dataset, DataLoader

# %%
from scipy.sparse.csgraph import connected_components
from scipy.spatial import cKDTree
from scipy.optimize import minimize
import scipy.linalg as linalg
from scipy.special import gamma, kv

# %%
import gstlearn as gl
import gstlearn.plot as gp
import gstlearn.document as gdoc
gdoc.setNoScroll()
# Out:
#     <style id="no-scroll-outputs">
#     /* cibles communes JupyterLab / Notebook 7 et fallback classique */
#     .jp-OutputArea-child,
#     .jp-OutputArea-output,
#     .jp-OutputArea,
#     .jp-RenderedText,
#     .jp-RenderedHTMLCommon,
#     .output_scroll,
#     .output_area .output_subarea {
#         max-height: none !important;
#         height: auto !important;
#         min-height: 0 !important;
#         overflow: visible !important;
#     }
#     /* blocs <pre> / code */
#     .jp-OutputArea-child pre,
#     .jp-OutputArea-output pre,
#     .jp-RenderedHTMLCommon pre,
#     .output_scroll pre {
#         max-height: none !important;
#         overflow: visible !important;
#     }
#     </style>

# %%
import sbi

from sbi.inference import NPE, NLE, SNPE
from sbi.analysis import pairplot
from sbi.utils import BoxUniform

from sbi.neural_nets import posterior_nn
from sbi.neural_nets.embedding_nets import CNNEmbedding

# %% [markdown]
# ## Variables

# %%
space_size = 30
time_size = 30
deepset_size = 1
missing_ratio = 0

train_size = 4000
test_size = 100

# %% [markdown]
# ## Utils

# %%
def add_missing_mask(batch, missing_ratio):
    nb_missing = int(space_size*missing_ratio)
    missings = np.sort(np.random.permutation(space_size)[:nb_missing])
    batch[:,:,:,missings] = 0
    mask = np.zeros_like(batch)
    mask[:,:,:,missings] = 1
    return np.concatenate([batch, mask], axis=1)

# %%
# Remark : advection (first param) had lowerbound and upperbound set to 0 => bug in build posterior

def create_prior():

    lower_bound = torch.as_tensor([-3, 0.05, 0.05, 0.1])
    upper_bound = torch.as_tensor([3, 0.25, 0.25, 1.])
    prior = BoxUniform(low=lower_bound, high=upper_bound)

    return prior

# %%
def simulate_matern_grid(theta, time_size=30, space_size=30, deepset_size=1):
    
    batch = []
    
    for th in theta :
        
        adv, range_time, range_space, std = int(th[0]), th[1], th[2], th[3]
        # adv, range_time, range_space, std = 0, th[0], th[1], th[2]
        
                
        model = gl.Model.createFromParam(gl.ECov.MATERN, ranges = [range_time,range_space], param = 1, sill = std**2, flagRange=False)

        shape_adv = abs(adv)+1

        grid = gl.DbGrid.create(
            nx = [time_size,space_size  + time_size*shape_adv],    
            dx = [1./time_size,1./space_size]
        )

        mesh = gl.MeshETurbo(grid)

        pop = gl.PrecisionOpMatrix(mesh, model.getCovAniso(0))
        
        for i in range(deepset_size):

            res = pop.simulateOne()
            res = res.reshape((time_size,space_size + time_size*shape_adv), order='F')

            t, s = np.meshgrid(np.arange(time_size), np.arange(space_size), indexing='ij')
            offset = t.copy() * abs(adv)
            s = s + offset


            if adv >= 0 :
                res = res[t,s]
            else :
                res = np.fliplr(res)
                res = res[t,s]
                res = np.fliplr(res)

            batch.append(res)

    batch = np.stack(batch)
    batch = np.expand_dims(batch,1)
    return torch.from_numpy(batch).to(torch.float32)

# %% [markdown]
# ## Inference

# %% [markdown]
# ### NPE

# %%
prior = create_prior()

# %%
theta = prior.sample((train_size,))
theta.shape
# Out:
# torch.Size([4000, 4])

# %%
# Remark : Can i save them ? then load them a each epoch 

x = simulate_matern_grid(theta)
x.shape
# Out:
# torch.Size([4000, 1, 30, 30])

# %%
plt.imshow(x[1,0])

# %%
# Remark : 2D CNN

embedding_net = CNNEmbedding(
    input_shape=(time_size,space_size,),
    in_channels=1,
    output_dim=20,
)

torch.any(torch.isnan(x)), torch.any(torch.isnan(embedding_net(x)))
# Out:
# (tensor(False), tensor(False))

# %% [raw]
# embedding_net(x)

# %%
# Remark : A bug here with "structured"

density_estimator = posterior_nn(model="maf", embedding_net=embedding_net, z_score_x="none")
# density_estimator = posterior_nn(model="maf", embedding_net=embedding_net, z_score_x="structured")

# %%
npe_cnn = NPE(prior=prior, density_estimator=density_estimator)

# %%
npe_cnn.append_simulations(theta,x).train(max_num_epochs=1000)
# Out:
#  Neural network successfully converged after 488 epochs.
# NFlowsFlow(
#   (net): Flow(
#     (_transform): CompositeTransform(
#       (_transforms): ModuleList(
#         (0): PointwiseAffineTransform()
#         (1): MaskedAffineAutoregressiveTransform(
#           (autoregressive_net): MADE(
#             (initial_layer): MaskedLinear(in_features=4, out_features=50, bias=True)
#             (context_layer): Linear(in_features=20, out_features=50, bias=True)
#             (blocks): ModuleList(
#               (0-1): 2 x MaskedFeedforwardBlock(
#                 (linear): MaskedLinear(in_features=50, out_features=50, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (final_layer): MaskedLinear(in_features=50, out_features=8, bias=True)
#           )
#         )
#         (2): RandomPermutation()
#         (3): MaskedAffineAutoregressiveTransform(
#           (autoregressive_net): MADE(
#             (initial_layer): MaskedLinear(in_features=4, out_features=50, bias=True)
#             (context_layer): Linear(in_features=20, out_features=50, bias=True)
#             (blocks): ModuleList(
#               (0-1): 2 x MaskedFeedforwardBlock(
#                 (linear): MaskedLinear(in_features=50, out_features=50, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (final_layer): MaskedLinear(in_features=50, out_features=8, bias=True)
#           )
#         )
#         (4): RandomPermutation()
#         (5): MaskedAffineAutoregressiveTransform(
#           (autoregressive_net): MADE(
#             (initial_layer): MaskedLinear(in_features=4, out_features=50, bias=True)
#             (context_layer): Linear(in_features=20, out_features=50, bias=True)
#             (blocks): ModuleList(
#               (0-1): 2 x MaskedFeedforwardBlock(
#                 (linear): MaskedLinear(in_features=50, out_features=50, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (final_layer): MaskedLinear(in_features=50, out_features=8, bias=True)
#           )
#         )
#         (6): RandomPermutation()
#         (7): MaskedAffineAutoregressiveTransform(
#           (autoregressive_net): MADE(
#             (initial_layer): MaskedLinear(in_features=4, out_features=50, bias=True)
#             (context_layer): Linear(in_features=20, out_features=50, bias=True)
#             (blocks): ModuleList(
#               (0-1): 2 x MaskedFeedforwardBlock(
#                 (linear): MaskedLinear(in_features=50, out_features=50, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (final_layer): MaskedLinear(in_features=50, out_features=8, bias=True)
#           )
#         )
#         (8): RandomPermutation()
#         (9): MaskedAffineAutoregressiveTransform(
#           (autoregressive_net): MADE(
#             (initial_layer): MaskedLinear(in_features=4, out_features=50, bias=True)
#             (context_layer): Linear(in_features=20, out_features=50, bias=True)
#             (blocks): ModuleList(
#               (0-1): 2 x MaskedFeedforwardBlock(
#                 (linear): MaskedLinear(in_features=50, out_features=50, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (final_layer): MaskedLinear(in_features=50, out_features=8, bias=True)
#           )
#         )
#         (10): RandomPermutation()
#       )
#     )
#     (_distribution): StandardNormal()
#     (_embedding_net): CNNEmbedding(
#       (cnn_subnet): Sequential(
#         (0): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (3): Conv2d(6, 12, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#         (4): ReLU(inplace=True)
#         (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (linear_subnet): FCEmbedding(
#         (net): Sequential(
#           (0): Linear(in_features=432, out_features=50, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=50, out_features=20, bias=True)
#           (3): ReLU()
#         )
#       )
#     )
#   )
# )

# %%
posterior = npe_cnn.build_posterior()

# %%
theta_test = prior.sample((test_size,))
theta_test[:,0] = torch.round(theta_test[:,0])
x_test = simulate_matern_grid(theta_test) 

limits = [[-3,3],[0.05,0.25],[0.05,0.25],[.1,1.]]
param_labels = ['advection', 'range time', 'range space', 'std']

# %%
k = 3

samples_cnn = posterior.sample((10_000,), x=x_test[k])

fig, axes = pairplot(
    samples_cnn,
    limits=limits,
    labels=param_labels,
    figsize=(8, 8),
    points=theta_test[k],
)
plt.suptitle("CNN Embeding", y=1.02)
plt.show()
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
# Remark : When adv=0, the posterior is right 

print(theta_test[k])
plt.imshow(x_test[k,0])
# Out:
# tensor([0.0000, 0.1374, 0.1380, 0.2235])

# %% [markdown]
# ### SNPE

# %%
seq_prior = create_prior()

NUM_ROUNDS = 5
NUM_SIMS_PER_ROUND = 1000

# %%
seq_theta_test = prior.sample((test_size,))
seq_theta_test[:,0] = torch.round(seq_theta_test[:,0])
seq_x_test = simulate_matern_grid(seq_theta_test)

# %%
seq_embedding_net = CNNEmbedding(
    input_shape=(time_size,space_size,),
    in_channels=1,
    output_dim=20,
)

# %%
seq_density_estimator = posterior_nn(model="maf", embedding_net=seq_embedding_net, z_score_x="none")

# %%
seq_proposal = seq_prior  
seq_posteriors = []  

seq_trainer = SNPE(seq_prior, density_estimator=seq_density_estimator)

for round_idx in range(NUM_ROUNDS):
    print(f"\n=== Round {round_idx + 1} ===")

    print(f"Simulating {NUM_SIMS_PER_ROUND} samples...")
    seq_theta = seq_prior.sample((NUM_SIMS_PER_ROUND,))
    seq_x = simulate_matern_grid(seq_theta)


    seq_trainer.append_simulations(seq_theta, seq_x, proposal=seq_proposal)

    print("Training...")
    seq_trainer.train(show_train_summary=True)

    seq_posterior = seq_trainer.build_posterior()
    seq_posteriors.append(seq_posterior)

    seq_proposal = seq_posterior.set_default_x(seq_x_test)

print("\n=== Done ===")
# Out:
# === Round 1 ===
# Simulating 1000 samples...
# Training...
#  Neural network successfully converged after 214 epochs.
#         -------------------------
#         ||||| ROUND 1 STATS |||||:
#         -------------------------
#         Epochs trained: 214
#         Best validation performance: -3.5179
#         -------------------------
#
#
# === Round 2 ===
# Simulating 1000 samples...
# Training...
# Using SNPE-C with atomic loss
#  Neural network successfully converged after 106 epochs.
#         -------------------------
#         ||||| ROUND 2 STATS |||||:
#         -------------------------
#         Epochs trained: 106
#         Best validation performance: 0.2542
#         -------------------------
#
#
# === Round 3 ===
# Simulating 1000 samples...
# Training...
# Using SNPE-C with atomic loss
#  Neural network successfully converged after 41 epochs.
#         -------------------------
#         ||||| ROUND 3 STATS |||||:
#         -------------------------
#         Epochs trained: 41
#         Best validation performance: 0.1819
#         -------------------------
#
#
# === Round 4 ===
# Simulating 1000 samples...
# Training...
# Using SNPE-C with atomic loss
#  Training neural network. Epochs trained: 41

# %%
seq_samples_across_rounds = [seq_posteriors[_].sample((1000,), x=seq_x_test, show_progress_bars=False) for _ in range(len(seq_posteriors))]
seq_snpe_samples = seq_posteriors[-1].sample((1000,), x=seq_x_test, show_progress_bars=False)

# %% [raw]
# TODO :
# - SNPE
# - Try "structured" again
# - More diagnostics
# - Add Missing Data
